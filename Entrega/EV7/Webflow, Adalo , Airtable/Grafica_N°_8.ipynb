# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/Webflow, Adalo , Airtable.csv')

df['Semana'] = pd.to_datetime(data['Semana'], format='%Y-%m-%d')

plt.figure(figsize=(12, 6))
plt.plot(df['Semana'], df['Webflow'], marker='o', label='Webflow', color='blue')
plt.plot(df['Semana'], df['Adalo, Inc'], marker='o', label='Adalo, Inc', color='orange')
plt.plot(df['Semana'], df['Airtable'], marker='o', label='Airtable', color='green')

plt.title('Comparación de Popularidad: Webflow, Adalo, Inc y Airtable', fontsize=14)
plt.xlabel('Semana', fontsize=12)
plt.ylabel('Popularidad (Porcentaje)', fontsize=12)
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
