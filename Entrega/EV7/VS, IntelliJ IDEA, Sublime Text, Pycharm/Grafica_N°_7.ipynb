# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/content/VS, IntelliJ IDEA, Sublime Text, Pycharm.csv')

df['Semana'] = pd.to_datetime(data['Semana'], format='%Y-%m-%d')

plt.figure(figsize=(12, 6))

plt.plot(df['Semana'], df['Visual Studio Code'], marker='o', label='Visual Studio Code', color='blue')
plt.plot(df['Semana'], df['IntelliJ IDEA'], marker='o', label='IntelliJ IDEA', color='red')
plt.plot(df['Semana'], df['Sublime Text'], marker='o', label='Sublime Text', color='green')
plt.plot(df['Semana'], df['PyCharm'], marker='o', label='PyCharm', color='orange')

plt.title('Comparación de Popularidad de IDEs: Visual Studio Code, IntelliJ IDEA, Sublime Text y PyCharm')
plt.xlabel('Semana')
plt.ylabel('Porcentaje de Búsqueda')
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
