# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('/content/Amazon Web Services, Microsoft Azure, Google Cloud.csv')

df['Semana'] = pd.to_datetime(data['Semana'], format='%Y-%m-%d')

plt.figure(figsize=(12, 6))
plt.plot(df['Semana'], df['Amazon Web Services'], marker='o', label='Amazon Web Services', color='blue')
plt.plot(df['Semana'], df['Microsoft Azure'], marker='o', label='Microsoft Azure', color='green')
plt.plot(df['Semana'], df['Google Cloud'], marker='o', label='Google Cloud', color='orange')

plt.title('Comparación de Popularidad de Servicios en la Nube: AWS, Azure y Google Cloud')
plt.xlabel('Semana')
plt.ylabel('Porcentaje de Búsqueda')
plt.xticks(rotation=45)
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
